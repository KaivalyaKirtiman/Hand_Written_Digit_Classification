# %%
import tensorflow
import matplotlib as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout

# %%
(x_train,y_train),(x_test,y_test)=tensorflow.keras.datasets.mnist.load_data()
# %matplotlib inline
fig,axs = plt.pyplot.subplots(4,4,figsize=(10,10) )
for i,ax in enumerate(axs.flat):
  ax.matshow(x_train[i])
  ax.axis("off")
  ax.set_title("Number {}".format(y_train[i]))
fig.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
x_train=x_train.reshape(x_train.shape[0],28,28,1)
x_test=x_test.reshape(x_test.shape[0],28,28,1)
x_train=x_train.astype("float32")
x_test=x_test.astype("float32")
x_train/=255
x_test/=255

# %%
Model=Sequential()
Model.add(Conv2D(28,kernel_size=(3,3),input_shape=(28,28,1)))
Model.add(MaxPooling2D(pool_size=(2,2)))
Model.add(Flatten())
Model.add(Dense(128,activation=tensorflow.nn.relu))
Model.add(Dropout(0.2))
Model.add(Dense(10,activation=tensorflow.nn.softmax))

# %%
Model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics="accuracy")
Model.fit(x=x_train,y=y_train,epochs=2)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 10s 3ms/step - loss: 0.2046 - accuracy: 0.9387
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0843 - accuracy: 0.9735

# %%
Model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0639 - accuracy: 0.9796
# [0.06393586099147797, 0.9796000123023987]
